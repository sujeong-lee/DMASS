# %% [markdown]
# # Number density and bias with real data

# %%
import os, sys, scipy
import esutil
import healpy as hp
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../code_py3/')
from cmass_modules import io
from utils import matchCatalogsbyPosition, hpHEALPixelToRaDec, HealPixifyCatalogs, spatialcheck
from xd import mixing_color_elg, assignELGProb, doVisualization_1d, XD_fitting_X
from run_DMASS_Y3 import priorCut_test
#from systematics import *

# %% [markdown]
# # Loading Catalogs

# %% [markdown]
# Lading Y3 Gold catalog

# %%
#loading y3 gold catalogs
input_path = '/n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/'
input_keyword = 'Y3_GOLD'
columns = \
['RA', 'DEC', 'HPIX_4096', 
'COADD_OBJECT_ID', 
'EBV_SFD98',
'SOF_CM_MAG_CORRECTED_G',
'SOF_CM_MAG_CORRECTED_R',
'SOF_CM_MAG_CORRECTED_I',
'SOF_CM_MAG_CORRECTED_Z',
'SOF_CM_MAG_ERR_G',
'SOF_CM_MAG_ERR_R',
'SOF_CM_MAG_ERR_I',
'SOF_CM_MAG_ERR_Z']
gold_st82 = io.SearchAndCallFits(path = input_path, keyword = input_keyword, columns=columns)
mask_magcut = priorCut_elg(gold_st82)
gold_st82 = gold_st82[mask_magcut]
# Out:
# Calling catalogs >>>
# Y3_GOLD_2_0_STRIPE82_000001.fits
# Y3_GOLD_2_0_STRIPE82_000002.fits
# Y3_GOLD_2_0_STRIPE82_000003.fits
# Y3_GOLD_2_0_STRIPE82_000004.fits
# Y3_GOLD_2_0_STRIPE82_000005.fits
# Y3_GOLD_2_0_STRIPE82_000006.fits
# Y3_GOLD_2_0_STRIPE82_000007.fits
# Y3_GOLD_2_0_STRIPE82_000008.fits
# Y3_GOLD_2_0_STRIPE82_000009.fits
# Y3_GOLD_2_0_STRIPE82_000010.fits
# Y3_GOLD_2_0_STRIPE82_000011.fits
# Y3_GOLD_2_0_STRIPE82_000012.fits
# Y3_GOLD_2_0_STRIPE82_000013.fits
# Y3_GOLD_2_0_STRIPE82_000014.fits
# Y3_GOLD_2_0_STRIPE82_000015.fits
# Y3_GOLD_2_0_STRIPE82_000016.fits
# Y3_GOLD_2_0_STRIPE82_000017.fits
# Y3_GOLD_2_0_STRIPE82_000018.fits
# Y3_GOLD_2_0_STRIPE82_000019.fits
# Y3_GOLD_2_0_STRIPE82_000020.fits
# Y3_GOLD_2_0_STRIPE82_000021.fits
# Y3_GOLD_2_0_STRIPE82_000022.fits
# Y3_GOLD_2_0_STRIPE82_000023.fits
# Y3_GOLD_2_0_STRIPE82_000024.fits
# Y3_GOLD_2_0_STRIPE82_000025.fits
# Y3_GOLD_2_0_STRIPE82_000026.fits
# Y3_GOLD_2_0_STRIPE82_000027.fits
# Y3_GOLD_2_0_STRIPE82_000028.fits
# Y3_GOLD_2_0_STRIPE82_000029.fits
# Y3_GOLD_2_0_STRIPE82_000030.fits
# Y3_GOLD_2_0_STRIPE82_000031.fits
# Y3_GOLD_2_0_STRIPE82_000032.fits
# Y3_GOLD_2_0_STRIPE82_000033.fits
# Y3_GOLD_2_0_STRIPE82_000034.fits
# Y3_GOLD_2_0_STRIPE82_000035.fits
# Y3_GOLD_2_0_STRIPE82_000036.fits
# Y3_GOLD_2_0_STRIPE82_000037.fits
# Y3_GOLD_2_0_STRIPE82_000038.fits
# Y3_GOLD_2_0_STRIPE82_000039.fits
# Y3_GOLD_2_0_STRIPE82_000040.fits
# Y3_GOLD_2_0_STRIPE82_000041.fits
# Y3_GOLD_2_0_STRIPE82_000042.fits
# Y3_GOLD_2_0_STRIPE82_000043.fits
# Y3_GOLD_2_0_STRIPE82_000044.fits
# Y3_GOLD_2_0_STRIPE82_000045.fits
# Y3_GOLD_2_0_STRIPE82_000046.fits
# Y3_GOLD_2_0_STRIPE82_000047.fits
# Y3_GOLD_2_0_STRIPE82_000048.fits
# Y3_GOLD_2_0_STRIPE82_000049.fits
# Y3_GOLD_2_0_STRIPE82_000050.fits
# Y3_GOLD_2_0_STRIPE82_000051.fits
# Y3_GOLD_2_0_STRIPE82_000052.fits
# Y3_GOLD_2_0_STRIPE82_000053.fits
# Y3_GOLD_2_0_STRIPE82_000054.fits
# Y3_GOLD_2_0_STRIPE82_000055.fits
# Y3_GOLD_2_0_STRIPE82_000056.fits
# Y3_GOLD_2_0_STRIPE82_000057.fits
# Y3_GOLD_2_0_STRIPE82_000058.fits
# Y3_GOLD_2_0_STRIPE82_000059.fits
# Y3_GOLD_2_0_STRIPE82_000060.fits
# Y3_GOLD_2_0_STRIPE82_000061.fits
# Y3_GOLD_2_0_STRIPE82_000062.fits
# Y3_GOLD_2_0_STRIPE82_000063.fits
# Y3_GOLD_2_0_STRIPE82_000064.fits
# Y3_GOLD_2_0_STRIPE82_000065.fits
# Y3_GOLD_2_0_STRIPE82_000066.fits
# Y3_GOLD_2_0_STRIPE82_000067.fits
# Y3_GOLD_2_0_STRIPE82_000068.fits
# Y3_GOLD_2_0_STRIPE82_000069.fits
# Y3_GOLD_2_0_STRIPE82_000070.fits
# Y3_GOLD_2_0_STRIPE82_000071.fits
# Y3_GOLD_2_0_STRIPE82_000072.fits
# Y3_GOLD_2_0_STRIPE82_000073.fits
# Y3_GOLD_2_0_STRIPE82_000074.fits
# Y3_GOLD_2_0_STRIPE82_000075.fits
# Y3_GOLD_2_0_STRIPE82_000076.fits
# Y3_GOLD_2_0_STRIPE82_000077.fits
# Y3_GOLD_2_0_STRIPE82_000078.fits
# Y3_GOLD_2_0_STRIPE82_000079.fits
# Y3_GOLD_2_0_STRIPE82_000080.fits
# Y3_GOLD_2_0_STRIPE82_000081.fits
# Y3_GOLD_2_0_STRIPE82_000082.fits
# Y3_GOLD_2_0_STRIPE82_000083.fits
# Y3_GOLD_2_0_STRIPE82_000084.fits
# Y3_GOLD_2_0_STRIPE82_000085.fits
# Y3_GOLD_2_0_STRIPE82_000086.fits
# Y3_GOLD_2_0_STRIPE82_000087.fits
# Y3_GOLD_2_0_STRIPE82_000088.fits
# Y3_GOLD_2_0_STRIPE82_000089.fits
# Y3_GOLD_2_0_STRIPE82_000090.fits
# Y3_GOLD_2_0_STRIPE82_000091.fits
# Y3_GOLD_2_0_STRIPE82_000092.fits
# Y3_GOLD_2_0_STRIPE82_000093.fits
# Y3_GOLD_2_0_STRIPE82_000094.fits
# Y3_GOLD_2_0_STRIPE82_000095.fits
# Y3_GOLD_2_0_STRIPE82_000096.fits
# Y3_GOLD_2_0_STRIPE82_000097.fits
# Y3_GOLD_2_0_STRIPE82_000098.fits
# Y3_GOLD_2_0_STRIPE82_000099.fits
# Y3_GOLD_2_0_STRIPE82_000100.fits
# Y3_GOLD_2_0_STRIPE82_000101.fits
# Y3_GOLD_2_0_STRIPE82_000102.fits
# Y3_GOLD_2_0_STRIPE82_000103.fits
# Y3_GOLD_2_0_STRIPE82_000104.fits
# Y3_GOLD_2_0_STRIPE82_000105.fits
# Y3_GOLD_2_0_STRIPE82_000106.fits
# Y3_GOLD_2_0_STRIPE82_000107.fits
# Y3_GOLD_2_0_STRIPE82_000108.fits
# Y3_GOLD_2_0_STRIPE82_000109.fits
# Y3_GOLD_2_0_STRIPE82_000110.fits
# Y3_GOLD_2_0_STRIPE82_000111.fits
# Y3_GOLD_2_0_STRIPE82_000112.fits
# Y3_GOLD_2_0_STRIPE82_000113.fits
# Y3_GOLD_2_0_STRIPE82_000114.fits
# Y3_GOLD_2_0_STRIPE82_000115.fits
# Y3_GOLD_2_0_STRIPE82_000116.fits
# Y3_GOLD_2_0_STRIPE82_000117.fits
# Y3_GOLD_2_0_STRIPE82_000118.fits
# Y3_GOLD_2_0_STRIPE82_000119.fits
# Y3_GOLD_2_0_STRIPE82_000120.fits
# Y3_GOLD_2_0_STRIPE82_000121.fits
# Y3_GOLD_2_0_STRIPE82_000122.fits
# Y3_GOLD_2_0_STRIPE82_000123.fits
# Y3_GOLD_2_0_STRIPE82_000124.fits
# Y3_GOLD_2_0_STRIPE82_000125.fits
# Y3_GOLD_2_0_STRIPE82_000126.fits
# Y3_GOLD_2_0_STRIPE82_000127.fits
# Y3_GOLD_2_0_STRIPE82_000128.fits
# Y3_GOLD_2_0_STRIPE82_000129.fits
# Y3_GOLD_2_0_STRIPE82_000130.fits
# Y3_GOLD_2_0_STRIPE82_000131.fits
# Y3_GOLD_2_0_STRIPE82_000132.fits
# Y3_GOLD_2_0_STRIPE82_000133.fits
# Y3_GOLD_2_0_STRIPE82_000134.fits
# Y3_GOLD_2_0_STRIPE82_000135.fits
# Y3_GOLD_2_0_STRIPE82_000136.fits
# Y3_GOLD_2_0_STRIPE82_000137.fits
# Y3_GOLD_2_0_STRIPE82_000138.fits
# Y3_GOLD_2_0_STRIPE82_000139.fits
# Y3_GOLD_2_0_STRIPE82_000140.fits
# Y3_GOLD_2_0_STRIPE82_000141.fits
# Y3_GOLD_2_0_STRIPE82_000142.fits
# Y3_GOLD_2_0_STRIPE82_000143.fits
# Y3_GOLD_2_0_STRIPE82_000144.fits
# Y3_GOLD_2_0_STRIPE82_000145.fits
# Y3_GOLD_2_0_STRIPE82_000146.fits
# Y3_GOLD_2_0_STRIPE82_000147.fits
# Y3_GOLD_2_0_STRIPE82_000148.fits
# Y3_GOLD_2_0_STRIPE82_000149.fits
# Y3_GOLD_2_0_STRIPE82_000150.fits
# Y3_GOLD_2_0_STRIPE82_000151.fits
# Y3_GOLD_2_0_STRIPE82_000152.fits
# Y3_GOLD_2_0_STRIPE82_000153.fits
# reading 1/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000001.fits
# reading 2/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000002.fits
# reading 3/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000003.fits
# reading 4/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000004.fits
# reading 5/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000005.fits
# reading 6/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000006.fits
# reading 7/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000007.fits
# reading 8/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000008.fits
# reading 9/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000009.fits
# reading 10/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000010.fits
# reading 11/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000011.fits
# reading 12/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000012.fits
# reading 13/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000013.fits
# reading 14/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000014.fits
# reading 15/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000015.fits
# reading 16/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000016.fits
# reading 17/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000017.fits
# reading 18/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000018.fits
# reading 19/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000019.fits
# reading 20/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000020.fits
# reading 21/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000021.fits
# reading 22/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000022.fits
# reading 23/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000023.fits
# reading 24/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000024.fits
# reading 25/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000025.fits
# reading 26/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000026.fits
# reading 27/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000027.fits
# reading 28/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000028.fits
# reading 29/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000029.fits
# reading 30/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000030.fits
# reading 31/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000031.fits
# reading 32/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000032.fits
# reading 33/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000033.fits
# reading 34/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000034.fits
# reading 35/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000035.fits
# reading 36/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000036.fits
# reading 37/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000037.fits
# reading 38/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000038.fits
# reading 39/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000039.fits
# reading 40/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000040.fits
# reading 41/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000041.fits
# reading 42/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000042.fits
# reading 43/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000043.fits
# reading 44/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000044.fits
# reading 45/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000045.fits
# reading 46/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000046.fits
# reading 47/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000047.fits
# reading 48/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000048.fits
# reading 49/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000049.fits
# reading 50/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000050.fits
# reading 51/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000051.fits
# reading 52/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000052.fits
# reading 53/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000053.fits
# reading 54/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000054.fits
# reading 55/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000055.fits
# reading 56/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000056.fits
# reading 57/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000057.fits
# reading 58/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000058.fits
# reading 59/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000059.fits
# reading 60/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000060.fits
# reading 61/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000061.fits
# reading 62/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000062.fits
# reading 63/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000063.fits
# reading 64/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000064.fits
# reading 65/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000065.fits
# reading 66/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000066.fits
# reading 67/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000067.fits
# reading 68/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000068.fits
# reading 69/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000069.fits
# reading 70/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000070.fits
# reading 71/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000071.fits
# reading 72/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000072.fits
# reading 73/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000073.fits
# reading 74/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000074.fits
# reading 75/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000075.fits
# reading 76/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000076.fits
# reading 77/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000077.fits
# reading 78/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000078.fits
# reading 79/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000079.fits
# reading 80/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000080.fits
# reading 81/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000081.fits
# reading 82/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000082.fits
# reading 83/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000083.fits
# reading 84/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000084.fits
# reading 85/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000085.fits
# reading 86/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000086.fits
# reading 87/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000087.fits
# reading 88/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000088.fits
# reading 89/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000089.fits
# reading 90/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000090.fits
# reading 91/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000091.fits
# reading 92/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000092.fits
# reading 93/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000093.fits
# reading 94/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000094.fits
# reading 95/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000095.fits
# reading 96/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000096.fits
# reading 97/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000097.fits
# reading 98/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000098.fits
# reading 99/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000099.fits
# reading 100/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000100.fits
# reading 101/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000101.fits
# reading 102/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000102.fits
# reading 103/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000103.fits
# reading 104/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000104.fits
# reading 105/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000105.fits
# reading 106/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000106.fits
# reading 107/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000107.fits
# reading 108/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000108.fits
# reading 109/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000109.fits
# reading 110/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000110.fits
# reading 111/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000111.fits
# reading 112/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000112.fits
# reading 113/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000113.fits
# reading 114/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000114.fits
# reading 115/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000115.fits
# reading 116/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000116.fits
# reading 117/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000117.fits
# reading 118/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000118.fits
# reading 119/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000119.fits
# reading 120/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000120.fits
# reading 121/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000121.fits
# reading 122/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000122.fits
# reading 123/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000123.fits
# reading 124/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000124.fits
# reading 125/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000125.fits
# reading 126/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000126.fits
# reading 127/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000127.fits
# reading 128/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000128.fits
# reading 129/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000129.fits
# reading 130/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000130.fits
# reading 131/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000131.fits
# reading 132/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000132.fits
# reading 133/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000133.fits
# reading 134/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000134.fits
# reading 135/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000135.fits
# reading 136/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000136.fits
# reading 137/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000137.fits
# reading 138/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000138.fits
# reading 139/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000139.fits
# reading 140/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000140.fits
# reading 141/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000141.fits
# reading 142/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000142.fits
# reading 143/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000143.fits
# reading 144/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000144.fits
# reading 145/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000145.fits
# reading 146/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000146.fits
# reading 147/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000147.fits
# reading 148/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000148.fits
# reading 149/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000149.fits
# reading 150/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000150.fits
# reading 151/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000151.fits
# reading 152/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000152.fits
# reading 153/153 /n/des/lee.5922/data/gold_cat_Y3/STRIPE82/feae9705305d4430993687930f1cc3ad/Y3_GOLD_2_0_STRIPE82_000153.fits

# %% [markdown]
# Loading eBOSS sample

# %%
filename = '/n/des/lee.5922/data/eboss_cat/eBOSS_ELG_full_ALLdata-vDR16.fits'
#filename = '/n/des/lee.5922/data/eboss_cat/eBOSS_ELG_clustering_data-SGC-vDR16.fits'
elg = esutil.io.read(filename)

# Add healpix index to ELG catalog
healConfig = {'map_inside':4096,
              'out_nside':4096,
              'nest':False}
elg = HealPixifyCatalogs(catalog=elg, healConfig=healConfig, ratag='RA', dectag = 'DEC')

# %% [markdown]
# Calling Y3 GOLD footprint map

# %%
# matching GOLD and ELG galaxies positions to find the ELG couterparts in GOLD
mg1, mg2, _ = esutil.htm.HTM(10).match(train_sample['RA'], train_sample['DEC'], gold_st82['RA'], \
                                     gold_st82['DEC'],2./3600, maxmatch=1)
clean_elg_data_sdss = train_sample[mg1]
clean_elg_data_des = gold_st82[mg2]
elg_mask = np.zeros(gold_st82.size, dtype=bool)
elg_mask[mg2] = 1
#clean_elg_data_des = gold_st82[elg_mask]
noelg = gold_st82[~elg_mask]

# %%
# save training samples
outdir = '../output/test_elg/train_cat/'
os.makedirs(outdir, exist_ok=True)
esutil.io.write( outdir+'train_sample_des.fits', clean_elg_data_des, clobber=True)
esutil.io.write( outdir+'train_sample_sdss.fits', clean_elg_data_sdss, clobber=True)
esutil.io.write( outdir+'train_no_sample_des.fits', noelg, clobber=True)

# %%
# Plotting footprint
spatialcheck([elg, clean_elg_data_des], 
             label = ['ELG', 'ELG in train'], convert = None, ratag='RA',dectag='DEC')

# %%
# save training samples
outdir = '../output/test_elg/train_cat/'
clean_elg_data_des = esutil.io.read( outdir+'train_sample_des.fits')
noelg = esutil.io.read( outdir+'train_no_sample_des.fits')
gold_st82 = np.hstack([clean_elg_data_des, noelg])

# %%
# Draw a random sample from the training sample to reduce the sample size for a fast run
# Put sample size you want 
n_sample =  int(clean_elg_data_des.size/10)  # train cmass sample size
n_sample_non = int(noelg.size/500)          # train non-cmass sample size

print('random sampling... ')
sampling_ind = np.random.choice(np.arange(clean_elg_data_des.size), size = n_sample)
clean_elg_data_des_sub = clean_elg_data_des[sampling_ind]
print('num of randomly sampled elg ', clean_elg_data_des_sub.size)
random_sampling_ind = np.random.choice(np.arange(noelg.size), size = n_sample_non )
noelg_sub = noelg[random_sampling_ind]
print('num of randomly sampled non-elg ', noelg_sub.size)
elg_fraction = clean_elg_data_des.size *1./(clean_elg_data_des.size + noelg.size)
print('elg_fraction (elg/non-cmass): ', elg_fraction)

# save the fraction of ELG galaxies in the training sample
# This number will be called and used when assigning the ELG probability to GOLD galaxies. 
outdir = '../output/test_elg/fitting/'
f = open(outdir+'elgfrac', 'w')
f.write('{:0.10f}'.format(elg_fraction))
f.close()
# Out:
# random sampling...
# num of randomly sampled elg  13310
# num of randomly sampled non-elg  47596
# elg_fraction (elg/non-cmass):  0.005562166420550828

# %% [markdown]
# # Comparison of colors

# %%
fig, ax =plt.subplots(figsize=(5,5))
ax.plot( clean_elg_data_sdss['g'], clean_elg_data_des['SOF_CM_MAG_CORRECTED_G'], '.', alpha=0.1  )
ax.plot( np.linspace(0,25,10), np.linspace(0,25,10), 'k--' )

ax.set_ylabel('des mag g')
ax.set_xlabel('eboss mag g')
ax.set_xlim(21.8, 22.8)
ax.set_ylim(21.8, 22.8)


fig, ax =plt.subplots(figsize=(5,5))
des_gr = clean_elg_data_des['SOF_CM_MAG_CORRECTED_G'] - clean_elg_data_des['SOF_CM_MAG_CORRECTED_R']
des_rz = clean_elg_data_des['SOF_CM_MAG_CORRECTED_R'] - clean_elg_data_des['SOF_CM_MAG_CORRECTED_Z']
ax.plot( clean_elg_data_sdss['gr'], des_gr, '.', label='g-r', alpha =0.1  )
ax.plot( clean_elg_data_sdss['rz'], des_rz, '.', label='r-z', alpha=0.1  )
ax.plot( np.linspace(0,2,10), np.linspace(0,2,10), 'k--' )

ax.set_ylabel('des color')
ax.set_xlabel('eboss color')
ax.set_xlim(0.2, 1.5)
ax.set_ylim(0.2, 1.5)
ax.legend()


fig, ax =plt.subplots(1,2, figsize=(10,5))
des_gr = clean_elg_data_des['SOF_CM_MAG_CORRECTED_G'] - clean_elg_data_des['SOF_CM_MAG_CORRECTED_R']
des_rz = clean_elg_data_des['SOF_CM_MAG_CORRECTED_R'] - clean_elg_data_des['SOF_CM_MAG_CORRECTED_Z']

eboss_gr = clean_elg_data_sdss['gr']
eboss_rz = clean_elg_data_sdss['rz']
ax[0].plot( eboss_gr, eboss_rz, '.', label='eBOSS', alpha =0.1  )
ax[1].plot( des_gr, des_rz, '.', label='DES Y3 GOLD', alpha =0.1  )

#ax.plot( np.linspace(0,2,10), np.linspace(0,2,10), 'k--' )

gr = np.linspace(0, 1, 10)
rz1 = 0.218 * gr + 0.571
rz2 = -0.555 * gr + 1.901
rz3 = 1./(-0.068) * (gr-0.457)
rz4 = 1./(0.112) * (gr-0.773)

for i in range(2):
    ax[i].plot(gr, rz1, 'k--')
    ax[i].plot(gr, rz2, 'k--')
    ax[i].plot(gr, rz3, 'k--')
    ax[i].plot(gr, rz4, 'k--')
    ax[i].set_ylabel('g-r')
    ax[i].set_xlabel('r-z')
    
    ax[i].set_xlim(0.2, 1.0)
    ax[i].set_ylim(0.3, 2.0)
    ax[i].legend(loc=1)

# %%
# Plotting footprint
#y3goldsam = esutil.io.read('/n/des/lee.5922/data/y3gold/Y3_GOLD_2_2_SPT_sam10_000001.fits')
y3goldsam = esutil.io.read('/n/des/lee.5922/data/y3gold/Y3_GOLD_2_2_SPT_sam100.fits')
randind=np.random.choice(y3goldsam.size, size=10000 )
spatialcheck([y3goldsam, clean_elg_data_des], 
             label = ['y3 gold', 'eBOSS ELG in training'], 
             convert = None, ratag='RA',dectag='DEC')

# %%
# This generates four columns of cmass training sample. order : mag r, mag i, (g-r), (r-i)
X_elg_true, X_elg_cov = mixing_color_elg(clean_elg_data_des_sub, 
                mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED'], 
                err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR'], 
                filter = ['G', 'R', 'I', 'Z'], full=True)

# This generates four columns of non-cmass training sample. order : mag r, mag i, (g-r), (r-i)
X_no_true, X_no_cov = mixing_color_elg(noelg_sub, 
                mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED'], 
                err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR'], 
                filter = ['G', 'R', 'I', 'Z'], full=True)

# %%
# Comparison. train vs. randoms from the fitted gaussian mixture model
filename = 'figure/hist_color_elg.png'
doVisualization_1d(data=[X_elg_true, X_no_true], 
                   labels = ['mag g', 'mag r', 'mag i', 'g-r', 'r-i', 'i-z'], 
                   ranges = None, 
                   name = ['train-elg', 'train-non'], 
                   color= ['tab:blue', 'grey'],
                   weight = [None,None], 
                   nbins=100, filename=filename)
# Out:
# Using central 98% to set range.

# %% [markdown]
# # Extreme Deconvolution Fitting

# %%
# number of gaussian mixtures
n_elg = None    # for fitting the cmass distributions
n_no = None       # for fitting the non-cmass distributions

# number of XD iteration. 
# I set this number small for a fast run but 
# should be run until the XD algorithm converges
n_iter_elg = 10
n_iter_no = 10
# tolerance
tol = 1E-5

# pickle filename
outdir = '../output/test_elg/fitting/'
os.makedirs(outdir, exist_ok=True)
elg_pickle = outdir+'gm_elg_Mgri_Cgriz.pkl'.format(n_elg)
no_pickle = outdir+'gm_no_Mgri_Cgriz.pkl'.format(n_no)

# %%
# XD Fitting. This will take a while 

mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED' ]
err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR']
filter = ['G', 'R', 'I', 'Z']

clf_elg = XD_fitting_X( X = X_elg_true, Xcov = X_elg_cov, pickleFileName = elg_pickle, 
                       mag=mag, err=err, filter=filter, 
                       n_cl = n_elg, n_iter = n_iter_elg, tol = tol, 
                       verbose = True, init_params= None)                 
clf_no = XD_fitting_X( X = X_no_true, Xcov = X_no_cov, pickleFileName = no_pickle, 
                    mag=mag, err=err, filter=filter, 
                    n_cl = n_no, n_iter = n_iter_no, tol = tol, 
                    verbose = True, init_params = None)

# %%
# callig saved pickles 
#clf_cmass = XD_fitting( None, pickleFileName = cmass_pickle)               
#clf_no = XD_fitting( None, pickleFileName = no_pickle)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-14-321eaa004c11> in <module>
#       1 # callig saved pickles
# ----> 2 clf_cmass = XD_fitting( None, pickleFileName = cmass_pickle)
#       3 clf_no = XD_fitting( None, pickleFileName = no_pickle)
#
# /n/des/lee.5922/programs/cosmolike/DMASS-algorithm/code_py3/xd.py in XD_fitting(data, pickleFileName, init_params, suffix, mag, err, filter, n_cl, n_iter, tol, verbose)
#     728         import pickle
#     729         f = open(pickleFileName)
# --> 730         pickle = pickle.load(f)
#     731         clf = pickle['retval']
#     732     else:
#
# /n/des/lee.5922/programs/anaconda3/envs/env_py3/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
# Drawing random samples from the fitted Gaussian mixture model
# If the model is correct, the random sample should match with the training sample
X_sample_elg = clf_elg.sample(100000)  # cmass model
X_sample_no = clf_no.sample(100000)        # non-cmass model

# %%
# Comparison. train vs. randoms from the fitted gaussian mixture model
filename = 'figure/test.png'
doVisualization_1d( data=[X_elg_true, X_sample_elg], 
                   labels = ['mag_g', 'mag r', 'mag i', 'g-r', 'r-i', 'r-z'], 
                   ranges = None, 
                   name = ['train', 'model'], 
                   weight = [None,None], 
                   nbins=100, filename=filename)

# Statistical significance tests
print ('T-test:')
for i in range(X_elg_true.shape[1]):
    res = scipy.stats.ttest_ind(X_elg_true[:,i], X_sample_elg[:,i])
    print(res)
print ('\nKS-test:')
for i in range(X_elg_true.shape[1]):
    res = scipy.stats.ks_2samp(X_elg_true[:,i], X_sample_elg[:,i])
    print (res)
# Out:
# Using central 98% to set range.
# T-test:
# Ttest_indResult(statistic=0.2908114287233584, pvalue=0.7711960763431636)
# Ttest_indResult(statistic=0.4360647655176027, pvalue=0.6627905710448272)
# Ttest_indResult(statistic=0.34762307964931144, pvalue=0.728123916713745)
# Ttest_indResult(statistic=-0.501415218723373, pvalue=0.6160799055285374)
# Ttest_indResult(statistic=0.1359284322455967, pvalue=0.8918780998666722)
# Ttest_indResult(statistic=-0.16459733489661507, pvalue=0.8692612226581744)
# Ttest_indResult(statistic=-0.27283132303683383, pvalue=0.7849833775644268)
#
# KS-test:
# KstestResult(statistic=0.018884117205108963, pvalue=0.0004536694662945651)
# KstestResult(statistic=0.006516055597295289, pvalue=0.6982741875004987)
# KstestResult(statistic=0.005471194590533468, pvalue=0.8714594368109619)
# KstestResult(statistic=0.03249126972201344, pvalue=3.294833730341902e-11)
# KstestResult(statistic=0.016940458302028505, pvalue=0.002332679947668982)
# KstestResult(statistic=0.04470252441773104, pvalue=7.761714815134197e-21)
# KstestResult(statistic=0.018245777610818942, pvalue=0.0007921192977064449)

# %%
# Comparison. train vs. randoms for non-cmass
filename = 'figure/test.png'
doVisualization_1d( data=[X_no_true, X_sample_no], 
                   labels = ['mag_g', 'mag r', 'mag i', 'g-r', 'r-i', 'i-z'], 
                   ranges = None, 
                   name = ['train', 'test'], 
                   weight = [None,None], 
                   nbins=100, filename=filename)

# Statistical significance tests
print ('T-test:')
for i in range(X_elg_true.shape[1]):
    res = scipy.stats.ttest_ind(X_no_true[:,i], X_sample_no[:,i])
    print(res)
print ('\nKS-test:')
for i in range(X_elg_true.shape[1]):
    res = scipy.stats.ks_2samp(X_no_true[:,i], X_sample_no[:,i])
    print (res)
# Out:
# Using central 98% to set range.
# T-test:
# Ttest_indResult(statistic=0.5572188713985159, pvalue=0.5773787426078316)
# Ttest_indResult(statistic=0.45549793104322966, pvalue=0.6487517257675359)
# Ttest_indResult(statistic=0.37547366855368225, pvalue=0.7073087654022951)
# Ttest_indResult(statistic=0.1336364404261066, pvalue=0.8936902495317975)
# Ttest_indResult(statistic=0.30363385440234303, pvalue=0.7614072844376578)
# Ttest_indResult(statistic=-9.571053273483468, pvalue=1.0736941137993888e-21)
# Ttest_indResult(statistic=-3.2904936452521563, pvalue=0.0010003519555469515)
#
# KS-test:
# KstestResult(statistic=0.029903386839230106, pvalue=1.7426752850182571e-25)
# KstestResult(statistic=0.006192622909488188, pvalue=0.1678255096782324)
# KstestResult(statistic=0.004294412975880291, pvalue=0.5901381925587472)
# KstestResult(statistic=0.020624411295066813, pvalue=2.3975211809376365e-12)
# KstestResult(statistic=0.03345865366837551, pvalue=8.467556016541725e-32)
# KstestResult(statistic=0.05739244306244223, pvalue=9.067070646786937e-93)
# KstestResult(statistic=0.02578105471047988, pvalue=4.722192564279941e-19)

# %%
mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED' ]
err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR']
filter = ['G', 'R', 'I', 'Z']

rand_ind = np.random.choice(gold_st82.size, size = 1000000)

# Assigning CMASS probabilities to Gold Y3 in Stripe 82.
# The probabilities are saved to 'CMASS_PROB' column 
gold_st82_test = assignELGProb(gold_st82[rand_ind], clf_elg, clf_no, 
                     cmass_fraction = elg_fraction, 
                     mag=mag, err=err, filter=filter, full=True )
# Out:
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %

# %%
outdir = '../output/test_elg/test_cat/'
esutil.io.write(outdir+'DeBOSS_ELG_ra10_20_decm40_m30.fits', gold_spt_prob, clobber=True)

# %%
# This generates four columns of cmass training sample. order : mag r, mag i, (g-r), (r-i)
X_elg_true, Xcov = mixing_color_elg(clean_elg_data_des, 
                mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED'], 
                err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR'], 
                filter = ['G', 'R', 'I', 'Z'], full=True)

# %%
# Generate Four columns of data : mag r, mag i, (g-r), (r-i)
X_delg_st82, Xcov = mixing_color_elg(gold_st82_test, 
                mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED'], 
                err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR'], 
                filter = ['G', 'R', 'I', 'Z'], full=True )

# %%
# Comparison plot for the training sample (cmass) vs. dmass sample 
# DMASS sample should be weighted by 'CMASS_PROB' column when plotting
filename = 'figure/hist_color_elg.png'
weight_elg = gold_st82_test['ELG_PROB']
doVisualization_1d( data=[X_elg_true, X_delg_st82], 
                   weight = [None, weight_elg],
                   labels = ['mag g', 'mag r', 'mag i', 'g-r', 'r-i', 'i-z', 'r-z'], 
                   #labels = ['mag g', 'mag r', 'mag i', 'g-r', 'r-z'], 
                   ranges = None, 
                   name = ['train', 'DES-ELG st82'], 
                   nbins=100, filename=filename)

# Statistical significance tests
from statsmodels.stats.weightstats import ttest_ind
for i in range(7):
    res = ttest_ind(X_elg_true[:,i], X_delg_st82[:,i], weights=(None, weight_elg))
    print(res[:-1])
for i in range(7):
    #KS test should be weighted (not weighted here)
    res = scipy.stats.ks_2samp(X_elg_true[:,i], X_delg_st82[:,i])
    print (res)
# Out:
# Using central 98% to set range.
# (2.2655505105542186, 0.02348044223991675)
# (1.0120699071700312, 0.31150638270632597)
# (4.5210515934558435, 6.158363971640015e-06)
# (2.686169879480808, 0.007228487561140592)
# (-10.553925572629065, 4.983123637179498e-26)
# (-0.980229662526337, 0.3269744633954724)
# (-5.012003358641666, 5.393190468214542e-07)
# KstestResult(statistic=0.547528767851911, pvalue=0.0)
# KstestResult(statistic=0.41774250832024884, pvalue=0.0)
# KstestResult(statistic=0.43058820783718604, pvalue=0.0)
# KstestResult(statistic=0.3677735413608396, pvalue=0.0)
# KstestResult(statistic=0.436753420144393, pvalue=0.0)
# KstestResult(statistic=0.2626319102314644, pvalue=0.0)
# KstestResult(statistic=0.3077675419242876, pvalue=0.0)

# %% [markdown]
# # Outside training region

# %% [markdown]
# Repeat for Y3 GOLD galaxies that are not in Stripe 82

# %%
# callig saved pickles 

outdir = '../output/test_elg/fitting/'
os.makedirs(outdir, exist_ok=True)
elg_pickle = outdir+'gm_elg_Mgri_Cgr_rz.pkl'
no_pickle = outdir+'gm_no_Mgri_Cgr_rz.pkl'
f = open(outdir+'elgfrac', 'r')
elg_fraction = float(f.readline())

clf_elg = XD_fitting_X( None, None, pickleFileName = elg_pickle)               
clf_no = XD_fitting_X( None, None, pickleFileName = no_pickle)

# %%
outdir = '../output/test_elg/train_cat/'
train_filename = outdir+'train_sample_des.fits'
clean_elg_data_des = esutil.io.read(train_filename)

# %%
# Calling Y3 GOLD in a small square area 

# columns to call
columns = \
['RA', 'DEC', 'HPIX_4096', 
'COADD_OBJECT_ID', 
'EBV_SFD98',
'SOF_CM_MAG_CORRECTED_G',
'SOF_CM_MAG_CORRECTED_R',
'SOF_CM_MAG_CORRECTED_I',
'SOF_CM_MAG_CORRECTED_Z',
'SOF_CM_MAG_ERR_G',
'SOF_CM_MAG_ERR_R',
'SOF_CM_MAG_ERR_I',
'SOF_CM_MAG_ERR_Z']
# Y3 Gold (SPT) catalog directory
input_path = '/n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/'

# magnitudes and corresponding error columns that will be used
# to assign the DMASS (ELG) probability
mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED' ]
err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR']
filter = ['G', 'R', 'I', 'Z']

# directory to save
outdir = '../output/test_elg/test_cat/'
os.makedirs(outdir, exist_ok=True)

# Y3 GOLD catalog is too large to load all at once. 
# I split the catalog into 17 chuncks and load one by one 
# to assign the DMASS(ELG) probability 
for i in range(1,18):
    # catalog name
    input_keyword = 'Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_0000{:02.0f}.fits'.format(i)
    gold_spt_i = io.SearchAndCallFits(path = input_path, keyword = input_keyword, columns=columns)
    gold_spt_i = gold_spt_i[priorCut_elg(gold_spt_i)]
    
    # assign probability
    gold_spt_prob_i = assignELGProb(gold_spt_i, clf_elg, clf_no, 
                     cmass_fraction = elg_fraction, 
                     mag=mag, err=err, filter=filter )
    
    # save fitsfile
    fitsname = 'DeBOSS_ELG_'+input_keyword
    print ('save to ', fitsname)
    esutil.io.write(outdir+fitsname, gold_spt_prob_i)
    
    # empty memory
    gold_spt_i, gold_spt_prob_i = None, None
# Out:
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000001.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000001.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000001.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000002.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000002.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000002.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000003.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000003.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000003.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000004.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000004.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000004.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000005.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000005.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000005.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000006.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000006.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000006.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000007.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000007.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000007.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000008.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000008.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000008.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000009.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000009.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000009.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000010.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000010.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000010.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000011.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000011.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000011.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000012.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000012.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000012.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000013.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000013.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000013.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000014.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000014.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000014.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000015.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000015.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000015.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000016.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000016.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000016.fits
#
# Calling catalogs >>>
# Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000017.fits
# reading 1/1 /n/des/lee.5922/data/gold_cat_Y3/SPT/701615bf64824498972491d545d1e4df/Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000017.fits
# calculate loglikelihood gaussian with multiprocessing module
# multiprocessing 100 %
# save to  DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000017.fits

# %%
# calling the final catalog 
input_path = '../output/test_elg/test_cat/'
input_keyword = 'Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000'
gold_spt_prob = io.SearchAndCallFits(path = input_path, keyword = input_keyword, columns=None)
#gold_spt_prob = gold_spt_prob[priorCut_elg(gold_spt_prob)]
# Out:
# Calling catalogs >>>
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000001.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000002.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000003.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000004.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000005.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000006.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000007.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000008.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000009.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000010.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000011.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000012.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000013.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000014.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000015.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000016.fits
# DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000017.fits
# reading 1/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000001.fits
# reading 2/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000002.fits
# reading 3/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000003.fits
# reading 4/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000004.fits
# reading 5/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000005.fits
# reading 6/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000006.fits
# reading 7/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000007.fits
# reading 8/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000008.fits
# reading 9/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000009.fits
# reading 10/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000010.fits
# reading 11/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000011.fits
# reading 12/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000012.fits
# reading 13/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000013.fits
# reading 14/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000014.fits
# reading 15/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000015.fits
# reading 16/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000016.fits
# reading 17/17 ../output/test_elg/test_cat/DeBOSS_ELG_Y3_GOLD_2_0_SPT_ra10_20_decm40_m30_000017.fits

# %%
X_delg, Xcov = mixing_color_elg(gold_spt_prob, 
                mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED'], 
                err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR'], 
                filter = ['G', 'R', 'I', 'Z'],
                full = True  )
X_elg_true, X_elg_cov = mixing_color_elg(clean_elg_data_des, 
                mag = ['SOF_CM_MAG_CORRECTED', 'SOF_CM_MAG_CORRECTED'], 
                err = ['SOF_CM_MAG_ERR', 'SOF_CM_MAG_ERR'], 
                filter = ['G', 'R', 'I', 'Z'], full=True)

# %%
filename = 'figure/test.png'
weight_elg = gold_spt_prob['ELG_PROB']
doVisualization_1d(data=[X_elg_true, X_delg], 
                   weight = [None, weight_elg],
                   labels = ['mag g', 'mag r', 'mag i', 'g-r', 'r-i', 'i-z', 'r-z'], 
                   ranges = None, 
                   name = ['train', 'delg'], 
                   nbins=100, 
                   filename=filename)

# Statistical significance tests
from statsmodels.stats.weightstats import ttest_ind
for i in range(4):
    res = ttest_ind(X_elg_true[:,i], X_delg[:,i], weights=(None, weight_elg))
    print(res)
for i in range(4):
    #KS test should be weighted (not weighted here)
    res = scipy.stats.ks_2samp(X_elg_true[:,i], X_delg[:,i])
    print (res)
# Out:
# Using central 98% to set range.
# (3.413881951722288, 0.0006406139160511165, 148709.79031407656)
# (2.5999685479895045, 0.009324151995009371, 148709.79031407656)
# (7.433004964527979, 1.0672360962936383e-13, 148709.79031407656)
# (1.2447828984640552, 0.21321352567723267, 148709.79031407656)
# KstestResult(statistic=0.5802903656404758, pvalue=0.0)
# KstestResult(statistic=0.4475155005347788, pvalue=0.0)
# KstestResult(statistic=0.4623501395994036, pvalue=0.0)
# KstestResult(statistic=0.36132759217216603, pvalue=0.0)

# %%
#outdir = '../output/test_elg/test_cat/'
#esutil.io.write(outdir+'DeBOSS_ELG_ra10_20_decm40_m30.fits', gold_spt_prob, clobber=True)

# %%
# compute number density
p01cut = gold_spt_prob['ELG_PROB'] > 0.01
ngal_elg = np.sum( gold_spt_prob['ELG_PROB'][p01cut])
ngal_total = gold_spt_prob.size
density = ngal_elg/ngal_total
print ('training sample number density: ', elg_fraction)
print ('ELG number density in GOLD Y3: ', density)
# Out:
# training sample number density:  0.0055621664
# ELG number density in GOLD Y3:  0.006109054496397531

# %%
# Plotting footprint
#y3goldsam = esutil.io.read('/n/des/lee.5922/data/y3gold/Y3_GOLD_2_2_SPT_sam10_000001.fits')
y3goldsam = esutil.io.read('/n/des/lee.5922/data/y3gold/Y3_GOLD_2_2_SPT_sam100.fits')
randind=np.random.choice(y3goldsam.size, size=10000 )
randind_spt=np.random.choice(gold_spt_prob.size, size=10000 )
spatialcheck([y3goldsam, clean_elg_data_des,gold_spt_prob[randind_spt] ], 
             label = ['y3 gold', 'ELG in training', 'test region'], 
             convert = None, ratag='RA',dectag='DEC')
