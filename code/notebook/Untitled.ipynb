# %%
from xd import *
from utils import *
import esutil
import healpy as hp
from systematics import *

from matplotlib import rc
import matplotlib.pylab as plt

#rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
#rc('text', usetex=True)
import sys, os
sys.path.insert(0, '/n/des/lee.5922/programs/cosmolike/MG_musigma/')

from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# /n/home00/lee.5922/.local/lib/python2.7/site-packages/subprocess32.py:472: RuntimeWarning: The _posixsubprocess module is not being used. Child process reliability may suffer if your program uses threads.
#   "program uses threads.", RuntimeWarning)

# %%
path = '/n/des/lee.5922/programs/cosmolike/MG_musigma/'

# %%
from plot_chain import plot_single, plot_triple, calling_public_planck_chains

chains = np.genfromtxt(path+'like/like_dmass_spt_bias_sam120000')[5000:,:-1]

planck_params = ['$\Omega_m$', r'$A_s$', '$n_s$', '$\Omega_b$','$h0$',r'$b$', r'$\sigma_8$']
figname = 'plots/test.png'


chain_names = ['']
truth = [0.307, 2.26e-09, 0.9655, 0.04, 0.6777, 2.0, 0.829]
#plot_triple([chains], 
#            [planck_params], 
#            None, figname, keep = None, chain_names = chain_names)

plot_single(chains, planck_params, truth, figname)
# Out:
# WARNING:chainconsumer.analysis:Parameter $\Omega_m$  in chain 0 is not constrained
# WARNING:chainconsumer.analysis:Parameter $n_s$  in chain 0 is not constrained
# WARNING:chainconsumer.analysis:Parameter $\Omega_b$  in chain 0 is not constrained
# WARNING:chainconsumer.analysis:Parameter $h0$  in chain 0 is not constrained
# WARNING:chainconsumer.analysis:Parameter $b$  in chain 0 is not constrained
# WARNING:chainconsumer.analysis:Parameter $\sigma_8$  in chain 0 is not constrained
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-d3dea7378dbf> in <module>()
#      13 #            None, figname, keep = None, chain_names = chain_names)
#      14
# ---> 15 plot_single(chains, planck_params, truth, figname)
#
# ...
