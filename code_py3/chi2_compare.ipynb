# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# In /users/PCON0003/warner785/.conda/envs/DES_env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /users/PCON0003/warner785/.conda/envs/DES_env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /users/PCON0003/warner785/.conda/envs/DES_env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
file_path = '/users/PCON0003/warner785/DMASSY3/code_py3/'

with open(file_path + 'unweighted_chi2_dmass_SP.txt') as dm0:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_unweight = [float(x) for x in dm0]
dm0.close()

with open(file_path + 'lin50_chi2_dmass_SP.txt') as dm1:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_lin50 = [float(x) for x in dm1]
dm1.close()

with open(file_path + 'lin107_chi2_dmass_SP.txt') as dm2:
#    w  = [float(x) for x in next(dmass).split()]
    chi2_linALL = [float(x) for x in dm2]
dm2.close()

with open(file_path + 'quadchi_update1_chi2_dmass_SP.txt') as dm3:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_quadchi50 = [float(x) for x in dm3]
dm3.close()

with open(file_path + 'quadchi_updateALL_chi2_dmass_SP.txt') as dm4:
#    w  = [float(x) for x in next(dmass).split()]
    chi2_quadchiALL = [float(x) for x in dm4]
dm4.close()

with open(file_path + 'linchi50_chi2_dmass_SP.txt') as dm5:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_2lin50 = [float(x) for x in dm5]
dm5.close()

with open(file_path + 'linchi107_chi2_dmass_SP.txt') as dm6:
#    w  = [float(x) for x in next(dmass).split()]
    chi2_2linALL = [float(x) for x in dm6]
dm6.close()

with open(file_path + 'quad_update1_chi2_dmass_SP.txt') as dm7:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_quad50 = [float(x) for x in dm7]
dm7.close()

with open(file_path + 'quad_updateALL_chi2_dmass_SP.txt') as dm8:
#    w  = [float(x) for x in next(dmass).split()]
    chi2_quadALL = [float(x) for x in dm8]
dm8.close()

with open(file_path + 'iterativeALL_chi2_dmass_SP.txt') as dm9:
#    w  = [float(x) for x in next(dmass).split()]
    chi2_quadALL_iter = [float(x) for x in dm9]
dm9.close()

with open(file_path + 'iterative50_chi2_dmass_SP.txt') as dm10:
#    w  = [float(x) for x in next(dmass).split()]
    chi2_quad50_iter = [float(x) for x in dm10]
dm10.close()

#lin50weights.fits //
#linALLweights.fits //
#quad50weights.fits //
#quadALLweights.fits //

#linchi2_50.fits //
#linchi2_ALL.fits //
#quadchi2_50.fits //
#quadchi2_ALL.fits //

import matplotlib.pyplot as plt

#plt.plot(chi2_unweight, color='red', marker='.', label='unweighted')
#plt.plot(chi2_lin50, marker='.', label='lin50weights')
#plt.plot(chi2_linALL, color='blue', marker='.', label='linALLweights')
#plt.plot(chi2_quad50, marker='.', label='quad50weights')
#plt.plot(chi2_quadALL, marker='.', label='quadALLweights')
#plt.plot(chi2_2lin50, marker='.', label='linchi2_50')
#plt.plot(chi2_2linALL, color = "purple", marker='.', label='linchi2_ALL')
plt.plot(chi2_quadchi50, marker='.', label='quadchi2_50')
plt.plot(chi2_quadchiALL, marker='.', label='quadchi2_ALL')
plt.plot(chi2_quad50_iter,marker='.', label='quadchi2_50_iterative')
plt.plot(chi2_quadALL_iter,marker='.', label='quadchi2_ALL_iterative') 

plt.legend()
plt.ylabel('chi2 value') 
plt.xlabel('SP map')
plt.title("Variation of chi2") 
plt.show()

# %%
file_path = '/users/PCON0003/warner785/DMASSY3/code_py3/'

with open(file_path + 'final_linear_chi2_dmass_SP.txt') as dm0:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_weight = [float(x) for x in dm0]
dm0.close()

with open(file_path + 'no_weight_chi2_dmass_SP.txt') as dm1:
#    w  = [float(x) for x in next(randoms).split()]
    chi2_noweight = [float(x) for x in dm1]
dm1.close()

print(chi2_weight)
# Out:
# [0.7679906896383528, 0.7103792821929397, 1.5229588750612972, 0.5588424235246333, 1.8192777066189276, 1.3470733393000967, 1.8083087325264586, 1.2168620947335156, 0.6021174545143998, 0.8491144327882177, 1.0043280170785345, 0.687186593493781, 0.7957828341900303, 0.6098105481166044, 2.1613602017965614, 1.3820989528412981, 2.1170745776189066, 0.6352304194884256, 2.513273187979014, 0.5015599076939183, 1.5136768436660952, 3.1312152321487186, 1.0480093599623568, 0.6532082400263083, 1.4037604876356564, 2.634279465110627, 1.5506872204298794, 0.7362751601961603, 1.7073467671031235, nan, 1.989820538486497, 2.146902032750846, 1.036241002605916, 0.7008969853527317]

# %%
import matplotlib.pyplot as plt

plt.plot(chi2_weight, marker='.', label='final_linear_weights')
plt.plot(chi2_noweight, marker='.', label='no_weight')

plt.legend()
plt.ylabel('chi2 value') 
plt.xlabel('SP map')
plt.title("Variation of chi2") 
plt.show()
